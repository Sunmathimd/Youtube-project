# %%
import pymongo
client = pymongo.MongoClient('mongodb+srv://sunmathidharmaraja:Sunmathimd@cluster0.fn1izv0.mongodb.net/')
db=client.youtubeproject
collection = db.myproject

# %%
youtube = collection.find_one()
youtube
# Out:
# {'_id': ObjectId('65320fb34e4225e7e16df3de'),
#  'channel_details': [{'Channel_id': 'UCaSut3DozeoXAaRJ62Ct0hw',
#    'Channel_name': 'colleen posey',
#    'Subscribers': '31700',
#    'Views': '8376897',
#    'Description': '',
#    'Total_videos': '32',
#    'playlist_id': 'UUaSut3DozeoXAaRJ62Ct0hw'}],
#  'video_details': [{'Channel_name': 'colleen posey',
#    'Channel_id': 'UCaSut3DozeoXAaRJ62Ct0hw',
#    'Video_id': 'KrofdMKlmcw',
#    'Title': 'cartoons only on cartoons',
#    'Tags': '',
#    'Thumbnail': 'https://i.ytimg.com/vi/KrofdMKlmcw/default.jpg',
#    'Description': 'bubble guppies the sunny side up show full house raggs phineas and ferb and wow wow wubbzy',
#    'Published_date': '2013-07-27T07:20:13Z',
#    'Views': '112086',
#    'Likes': '94',
#    'Comments': '0',
#    'Favorite_count': '0'},
#   {'Channel_name': 'colleen posey',
#    'Channel_id': 'UCaSut3DozeoXAaRJ62Ct0hw',
#    'Video_id': 'HoJfIGBjhNg',
#    'Title': 'cartoons on DVD',
#    'Tags': '',
# ...

# %%
import mysql.connector


mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="", 
)

print(mydb)
mycursor = mydb.cursor(buffered=True)

# %%
mycursor.execute("CREATE DATABASE youtube")

# %%
mycursor.execute("USE youtube")

# %%
mycursor.execute('''CREATE TABLE channel_details (channel_id VARCHAR(255),
                                                   Channel_name VARCHAR(255),
                                                   Subscribers INT,
                                                   Views INT,
                                                   Description TEXT,
                                                   Total_videos INT,
                                                   Playlist_id VARCHAR(255))''')

# %%
mycursor.execute('''CREATE TABLE video_details(Channel_name VARCHAR(255),
                                              Channel_id VARCHAR(255),
                                              Video_id VARCHAR(255),
                                              Title TEXT,
                                              Tags VARCHAR(255),
                                              Thumbnail TEXT,
                                              Description TEXT,
                                              Published_date TEXT,
                                              Views INT,
                                              Likes INT,
                                              Comments TEXT,
                                              Favorite_count INT)''')

# %%
mycursor.execute('''CREATE TABLE comment_details(Comment_id VARCHAR(355),
                                                 Video_id VARCHAR(355),
                                                 Comment_text TEXT,
                                                 Comment_author VARCHAR(355),
                                                 Comment_posted_date TEXT,
                                                 Like_count INT,
                                                 Reply_count INT)''')

# %%
sql = '''INSERT INTO channel_details(channel_id,
                                     Channel_name,
                                     Subscribers,
                                     Views,
                                     Description,
                                     Total_videos,
                                     Playlist_id)VALUES(%s,%s,%s,%s,%s,%s,%s)'''
val = tuple(youtube['channel_details'][0].values())
mycursor.execute(sql,val)
mydb.commit()

# %%
sql = '''INSERT INTO video_details(Channel_name,
                                   Channel_id,
                                   Video_id,
                                   Title,
                                   Tags,
                                   Thumbnail,
                                   Description,
                                   Published_date,
                                   Views,
                                   Likes,
                                   Comments,
                                   Favorite_count)VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
for i in youtube['video_details']:
     val = tuple(i.values())
mycursor.execute(sql,val)
mydb.commit()

# %%
sql = '''INSERT INTO comment_details(Comment_id,
                                     Video_id,
                                     Comment_text,
                                     Comment_author,
                                     Comment_posted_date,
                                     Like_count,
                                     Reply_count)VALUES(%s,%s,%s,%s,%s,%s,%s)'''
for j in youtube['comment_details']:
    val = tuple(j.values())
    mycursor.execute(sql,val)
mydb.commit()

# %%
def sql_main(channel):
    sql_cd= '''INSERT INTO channel_details(channel_id,Channel_name,Subscribers,Views,Description,Total_videos,Playlist_id)VALUES(%s,%s,%s,%s,%s,%s,%s)'''
    val = tuple(youtube['channel_details'][0].values())
    mycursor.execute(sql_cd,val)

sql_vd = '''INSERT INTO video_details(Channel_name,Channel_id,Video_id,Title,Tags,Thumbnail,Description,Published_date,Views,Likes,Comments,Favorite_count)VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
for i in youtube['video_details']:
     val = tuple(i.values())
mycursor.execute(sql_vd,val)

sql_cod = '''INSERT INTO comment_details(Comment_id,Video_id,Comment_text,Comment_author,Comment_posted_date,Like_count,Reply_count)VALUES(%s,%s,%s,%s,%s,%s,%s)'''
for j in youtube['comment_details']:
    val = tuple(j.values())
    mycursor.execute(sql_cod,val)
mydb.commit()

# %%
youtube.keys()
# Out:
# dict_keys(['_id', 'channel_details', 'video_details', 'comment_details'])

# %%
youtube['channel_details']
# Out:
# [{'Channel_id': 'UCaSut3DozeoXAaRJ62Ct0hw',
#   'Channel_name': 'colleen posey',
#   'Subscribers': '31700',
#   'Views': '8376897',
#   'Description': '',
#   'Total_videos': '32',
#   'playlist_id': 'UUaSut3DozeoXAaRJ62Ct0hw'}]

# %%
if questions == '1. What are the names of all the videos and their corresponding channels?':
    mycursor.execute("""SELECT title AS video_Title, channel_name AS Channel_Name FROM videos ORDER BY channel_name""")
    df = pd.DataFrame(mycursor.fetchall(),columns=mycursor.column_names)
    st.write(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\sunma\OneDrive\Documents\Vscode1\youtube.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sunma/OneDrive/Documents/Vscode1/youtube.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> if questions == '1. What are the names of all the videos and their corresponding channels?':
#       <a href='vscode-notebook-cell:/c%3A/Users/sunma/OneDrive/Documents/Vscode1/youtube.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a>     mycursor.execute("""SELECT title AS video_Title, channel_name AS Channel_Name FROM videos ORDER BY channel_name""")
#       <a href='vscode-notebook-cell:/c%3A/Users/sunma/OneDrive/Documents/Vscode1/youtube.ipynb#X25sZmlsZQ%3D%3D?line=2'>3</a>     df = pd.DataFrame(mycursor.fetchall(),columns=mycursor.column_names)
#
# NameError: name 'questions' is not defined
